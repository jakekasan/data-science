# %% [markdown]
# # Title
#
# Markdown code to be written... introduce dataset and sum up results.

# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn import neighbors
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

#plt.figure(figsize=(15,15))

# %%
DATA_PATH = "../data/wine-quality/"
RED_WINE_FILENAME = "winequality-red.csv"
WHITE_WINE_FILENAME = "winequality-white.csv"

# %%
redWine = pd.read_csv(DATA_PATH + RED_WINE_FILENAME,sep=";")
whiteWine = pd.read_csv(DATA_PATH + WHITE_WINE_FILENAME,sep=";")

# %%
redWine = redWine.dropna()
whiteWine = whiteWine.dropna()

# %%
redWine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
# fixed acidity           1599 non-null float64
# volatile acidity        1599 non-null float64
# citric acid             1599 non-null float64
# residual sugar          1599 non-null float64
# chlorides               1599 non-null float64
# free sulfur dioxide     1599 non-null float64
# total sulfur dioxide    1599 non-null float64
# density                 1599 non-null float64
# pH                      1599 non-null float64
# sulphates               1599 non-null float64
# alcohol                 1599 non-null float64
# quality                 1599 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 162.4 KB

# %%
whiteWine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
# fixed acidity           4898 non-null float64
# volatile acidity        4898 non-null float64
# citric acid             4898 non-null float64
# residual sugar          4898 non-null float64
# chlorides               4898 non-null float64
# free sulfur dioxide     4898 non-null float64
# total sulfur dioxide    4898 non-null float64
# density                 4898 non-null float64
# pH                      4898 non-null float64
# sulphates               4898 non-null float64
# alcohol                 4898 non-null float64
# quality                 4898 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 497.5 KB

# %%
x_train, x_test, y_train, y_test = train_test_split(redWine.drop("quality",axis=1),redWine["quality"],test_size=0.33,random_state=42)

# %%
redWine.describe()
# plt.hist(redWine["fixed acidity"])
# plt.show()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
pd.crosstab(redWine["quality"],redWine["citric acid"].apply(lambda x: round(x,1))).plot(kind="bar",figsize=(15,15))
# here we see that the higher citric acid values are more prevelant with higher quality wine

# %%
pd.crosstab(redWine["quality"],redWine["alcohol"].apply(lambda x: round(x))).plot(kind="bar",figsize=(15,15))
# higher alcohol content = higher wine "quality"

# %%
plt.figure(figsize=(15,15))
pd.crosstab(redWine["quality"],redWine["volatile acidity"].apply(lambda x: round(x,1))).plot(kind="bar",figsize=(15,15))

# %%
def plotHistograms(df,col,cats,target,bins):
    plt.figure(figsize=(15,15))
    for cat in sorted(cats):
        value,bins = np.histogram(df.loc[(df[col] == cat),target],bins=bins)
        value = [x/sum(value) for x in value]
        #print(value)
        #return
        plt.plot(bins[1:],value,label=cat,linewidth=6.0,alpha=0.5)
        
    plt.legend(loc="upper right")
    plt.show()
    
plotHistograms(redWine,"quality",redWine["quality"].unique(),"volatile acidity",np.linspace(0.0,1.6,17))

# (value,bins,_) = plt.hist(redWine.loc[(redWine["quality"] == 5),"volatile acidity"],bins=np.linspace(0.0,1.6,17))
# print(value,bins)
# plt.plot(bins[1:],value)
# plt.show()

# %%
len((np.linspace(0.1,1.6,16)))
# Out:
# 16

# %%
redWine["quality"].unique()
# Out:
# array([5, 6, 7, 4, 8, 3])

# %%
plotHistograms(redWine,"quality",redWine["quality"].unique(),"alcohol",np.linspace(7,15,9))

# %%
plotHistograms(redWine,"quality",redWine["quality"].unique(),"citric acid",np.linspace(-0.1,1.0,11))

# %%
# scale the relevant columns

def myScaler(df,ignore=None):
    for col in df.columns:
        if col == ignore:
            continue
        df[col] = df[col].apply(lambda x: (x-min(df[col]))/(max(df[col])-min(df[col])))
    return df

# %%
df = myScaler(redWine,ignore="quality")

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        0.329171          0.279329     0.270976        0.112247
# std         0.154079          0.122644     0.194801        0.096570
# min         0.000000          0.000000     0.000000        0.000000
# 25%         0.221239          0.184932     0.090000        0.068493
# 50%         0.292035          0.273973     0.260000        0.089041
# 75%         0.407080          0.356164     0.420000        0.116438
# max         1.000000          1.000000     1.000000        1.000000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.125988             0.209506              0.142996     0.490211
# std       0.078573             0.147326              0.116238     0.138571
# min       0.000000             0.000000              0.000000     0.000000
# 25%       0.096828             0.084507              0.056537     0.406021
# 50%       0.111853             0.183099              0.113074     0.490455
# 75%       0.130217             0.281690              0.197880     0.570117
# max       1.000000             1.000000              1.000000     1.000000
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      0.449695     0.196496     0.311228     5.636023
# std       0.121564     0.101501     0.163949     0.807569
# min       0.000000     0.000000     0.000000     3.000000
# 25%       0.370079     0.131737     0.169231     5.000000
# 50%       0.448819     0.173653     0.276923     6.000000
# 75%       0.519685     0.239521     0.415385     6.000000
# max       1.000000     1.000000     1.000000     8.000000

# %%
# run nearest neighbours
x_train, x_test, y_train, y_test = train_test_split(df.drop("quality",axis=1),df["quality"],test_size=0.33,random_state=42)

knn_model = neighbors.KNeighborsClassifier(30,weights="distance")

# %%
knn_model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=30, p=2,
#            weights='distance')

# %%
knn_model.score(x_test,y_test)
# Out:
# 0.634469696969697

# %%
from keras import Dense,Sequential
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-126-c66e22bfa1a1> in <module>()
# ----> 1 from keras import Dense,Sequential
#
# ~/coding/data-science/wine-quality/venv/lib/python3.6/site-packages/keras/__init__.py in <module>()
#       1 from __future__ import absolute_import
#       2
# ----> 3 from . import utils
#       4 from . import activations
#       5 from . import applications
#
# ~/coding/data-science/wine-quality/venv/lib/python3.6/site-packages/keras/utils/__init__.py in <module>()
#       4 from . import data_utils
#       5 from . import io_utils
# ----> 6 from . import conv_utils
#       7
#       8 # Globally-importable utils.
#
# ~/coding/data-science/wine-quality/venv/lib/python3.6/site-packages/keras/utils/conv_utils.py in <module>()
#       7 from six.moves import range
#       8 import numpy as np
# ----> 9 from .. import backend as K
#      10
#      11
#
# ~/coding/data-science/wine-quality/venv/lib/python3.6/site-packages/keras/backend/__init__.py in <module>()
#      82 elif _BACKEND == 'tensorflow':
#      83     sys.stderr.write('Using TensorFlow backend.\n')
# ---> 84     from .tensorflow_backend import *
#      85 else:
#      86     raise ValueError('Unknown backend: ' + str(_BACKEND))
#
# ~/coding/data-science/wine-quality/venv/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in <module>()
#       3 from __future__ import print_function
#       4
# ----> 5 import tensorflow as tf
#       6 from tensorflow.python.training import moving_averages
#       7 from tensorflow.python.ops import tensor_array_ops
#
# ModuleNotFoundError: No module named 'tensorflow'
